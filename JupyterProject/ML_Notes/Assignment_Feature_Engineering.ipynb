# %% [markdown]
# # Assignment: Feature Engineering with the Heart Disease Dataset
#
# ### Dataset Description
# This dataset contains information collected from patients related to their health status and risk of heart disease. The goal is to apply feature engineering techniques to prepare the data for machine learning models that predict whether or not a patient has heart disease.
#
# #### Features:
# - **age**: Age of the patient
# - **sex**: Gender (1 = male; 0 = female)
# - **cp**: Chest pain type (0–3)
# - **trestbps**: Resting blood pressure (in mm Hg)
# - **chol**: Serum cholesterol in mg/dl
# - **fbs**: Fasting blood sugar > 120 mg/dl (1 = true; 0 = false)
# - **restecg**: Resting electrocardiographic results (0–2)
# - **thalach**: Maximum heart rate achieved
# - **exang**: Exercise-induced angina (1 = yes; 0 = no)
# - **oldpeak**: ST depression induced by exercise
# - **slope**: The slope of the peak exercise ST segment
# - **ca**: Number of major vessels (0–3) colored by fluoroscopy
# - **thal**: Thalassemia (1 = normal; 2 = fixed defect; 3 = reversible defect)
# - **target**: Heart disease (1 = has disease, 0 = no disease)
#
# ### Instructions
# You are required to perform the following tasks using the dataset `heart.csv`. Make sure to write clean, well-commented code and explain each step briefly.
#
# ### Questions
#
# **1. Load the dataset and display the first 5 rows.**
# - Check the shape and column types of the data.
#
# **2. Check for missing values.**
# - If there are any, describe how you would handle them (no need to impute unless required).
#
# **3. Perform binning on the following variables:**
# - `age`: into age groups like '30s', '40s', ..., '70s'.
# - `chol`: into levels: 'Normal', 'Borderline', 'High'.
#
# **4. Create the following new features:**
# - `pulse_age_ratio`= `thalach` divided by (`age` + 1)
#
# **5. Encode categorical variables using one-hot encoding.**
# - Include: `sex`, `cp`, `fbs`, `restecg`, `exang`, `slope`, `thal`, and the two new binned features
# - Drop the first category in each to avoid multicollinearity
#
# **6. Standardize the following numeric features:**
# - `age`, `trestbps`, `chol`, `thalach`, `oldpeak`, `pulse_age_ratio`
# - Use `StandardScaler` from scikit-learn
#
# **7. Export the final cleaned and processed dataset**
# - Save it as `heart_disease_cleaned.csv`
#
# ---
#
# ### Deliverables
# - A Jupyter notebook with all code and outputs
# - Your final CSV file exported from the notebook

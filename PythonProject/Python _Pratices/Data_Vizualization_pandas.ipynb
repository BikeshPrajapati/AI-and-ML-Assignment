# %%
import pandas as pd
import seaborn as sns

df_tips = pd.read_csv('tips.csv')

df_tips
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3
#       4 df_tips = pd.read_csv('tips.csv')
#       5
#
# File ~\PycharmProjects\PythonProject\.venv\Lib\site-packages\seaborn\__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File ~\PycharmProjects\PythonProject\.venv\Lib\site-packages\seaborn\rcmod.py:3
#       1 """Control plot style and scaling using the matplotlib rcParams interface."""
#       2 import functools
# ----> 3 import matplotlib as mpl
#       4 from cycler import cycler
#       5 from . import palettes
#
# File ~\PycharmProjects\PythonProject\.venv\Lib\site-packages\matplotlib\__init__.py:161
# ...

# %%
#scatterplot
sns.scatterplot(data= df_tips, x = 'total_bill', y= 'tip', hue='time', size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#create Scatter plot
sns.relplot(data = df_tips, x ='total_bill',y ='tip', size='size',hue= 'time')

# %%
import matplotlib.pyplot as plt

sns.scatterplot(data = df_tips, x='total_bill',y ='tip',hue = 'time', size ='size')
plt.xlabel("Total bills")
plt.ylabel("Tips amount")
# Out:
# Text(0, 0.5, 'Tips amount')

# %%
#create line plot
import pandas as pd

frim = pd.read_csv(r"C:\Users\bkies\Downloads\fmri.csv")\

# %%
frim
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x='timepoint',y='signal', data = frim)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
#create bar plot
titanic = pd.read_csv(r"C:\Users\bkies\Downloads\titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x= 'class', y= 'fare', data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import matplotlib.pyplot as plt
sns.barplot(data = titanic, x = 'class', y = 'fare', errorbar= None, hue = 'sex')
plt.xlabel("Type of class")
plt.ylabel("Fare Amount")
plt.title("Average Fare by Class and Gender on the Titanic")
# Out:
# Text(0.5, 1.0, 'Average Fare by Class and Gender on the Titanic')

# %%
# Seaborn Histogram

# distribution of conitniios variable based on bins - ranges
# detect belll curve -> Normal distribution
# Skeweness (left_skewed or right_skewed)
# outliter or ususal gaps
#helpful for EDA
iris = pd.read_csv('iris.csv')
sns.set_style("whitegrid")
sns.histplot(data = iris, x ='petal_length' )
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %%
import matplotlib.pyplot as plt

target ='species'
feature_cols = [col for col in iris.columns if col != target]

for col in feature_cols:
    plt.figure(figsize=(6,4))
    iris[col].hist(bins=20)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in feature_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(iris[col], kde=True, bins=30, color='blue')
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
#box plot

import pandas as pd


data = {
    'values':[2,4,6,7,7,7,8,9,11,12,12,16,17,19,50]
}

df = pd.DataFrame(data)

# %%
iris[iris.loc[:,"sepal_length"] > 6]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# ..            ...          ...           ...          ...         ...
# 144           6.7          3.3           5.7          2.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
#
# [61 rows x 5 columns]

# %%
Q1 = df['values'].quantile(0.25)

# %%
Q3 = df['values'].quantile(0.75)

# %%
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns

sns.boxplot(x ='day',y='total_bill', data = df_tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
numeric_cols = df_tips.select_dtypes(include="number")

# Create the box plots in one figure
plt.figure(figsize=(1000, 5))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(1, len(numeric_cols), i)
    sns.boxplot(y=df_tips[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
corr = df_tips.corr(numeric_only=True)

corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,cmap='cool',annot= True)
# Out:
# <Axes: >

# %%
df = pd.read_csv('regression_dataset.csv')

# %%
df
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     0.671945  -1.183056   0.384202  -1.269999  -0.994429   0.249548
# 1    -0.265605  -0.150117  -0.399878  -2.090303  -0.114641   0.264268
# 2    -0.921860  -0.721738  -1.003957  -0.083438   0.207267   0.069344
# 3     0.473472  -0.099094  -0.267641   0.951550   0.846771  -2.127227
# 4    -1.683438  -1.234349  -0.805870  -0.562168   0.964852   1.615583
# ..         ...        ...        ...        ...        ...        ...
# 695  -0.589272  -1.545730  -1.092164   0.475168   0.834751   0.913772
# 696  -1.975467   0.599929  -0.939335   0.486502  -0.144088  -1.209695
# 697  -1.295079  -1.503143  -0.335785   0.073318   1.669022  -0.259591
# 698   0.107444   1.294986   0.387371   0.850079   0.323185   1.283817
# 699  -1.478522   0.343618  -0.719844  -0.115648  -0.460639   1.057122
#
#      feature_7      target
# 0     0.668840   35.937485
# 1    -0.170258  -54.279780
# 2    -1.449645 -104.035854
# ...

# %%
df_features = df.drop(columns=["target"])
corr = df_features.corr()

# %%
sns.heatmap(corr, cmap= 'coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
df_tips = pd.read_csv('tips.csv')

# %%
df_tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(df_tips['total_bill'], kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(df_tips, x= 'day', y= 'total_bill', hue ='day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(df_tips, x= 'total_bill', y='tip', hue ='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(df_tips, x= 'total_bill',y ='tip', hue = 'sex')

# %%
df_tips["sex"].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

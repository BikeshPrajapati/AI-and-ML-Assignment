# %%
import mysql.connector

try:
    print("Connecting to MySql database")
    with mysql.connector.connect(host= "localhost",user = "root",password = "Bikesh123") as dataBase:
        print("Connected to MySQL database")
        connection = dataBase.cursor()
        print("Creating database called: bikeshdb")
        connection.execute("CREATE DATABASE IF NOT EXISTS bikeshdb")
        print("Database created successfully")
        connection.execute("SHOW TABLES")

except mysql.connector.Error as err:
    print("Error : {err}")
# Out:
# Connecting to MySql database
# Connected to MySQL database
# Creating database called: bikeshdb
# Database created successfully
# Error : {err}

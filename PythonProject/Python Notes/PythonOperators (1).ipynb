# %% [markdown]
# #### Python Operators
#
# ##### Operators are special symbols that perform operations on variables and values.

# %%
print(9 + 11)

# walrus :=

# here + is an operator

# %% [markdown]
# ### Types of Python Operators
#
# #### Here's a list of different types of Python operators that we will learn in this tutorial.
#
# 1. Arithmetic Operators
# 2. Assignment Operators
# 3. Comparison Operators
# 4. Logical Operators
# 5. Membership operators

# %% [markdown]
# #### 1. Python Arithmetic Operators
# - Arithmetic operators are used to perform mathematical operations like `addition`, `subtraction`, `multiplication`, etc.

# %%
a = 6
b = 4

# addition
print ('Sum: ', a + b)
#
# subtraction
print ('Subtraction: ', a - b)
#
# multiplication
print ('Multiplication: ', a * b)
#
# division
print ('Division: ', a / b)
#
# floor division
print ('Floor Division: ', a // b) # 3

# divisor , dividend, reminder
#

print ('Modulo: ', a % b)
# #
# a to the power b
print ('Power: ', a ** b) # 6**4 = 6*6*6*6

# %%
number = int(input("ENter a number :"))

print(number%2)

# %% [markdown]
# ## Coding Test
#
# ### We are going build a calculator using python's `input` function where we :
# 1. Take input-1 from user and store in variable called `number_1`.
# 2. Take input-2 from user and store in variable called `number_2`.
# 3. Do operations like subtract and divide using python operators.

# %%
number_1 = int(input('Enter first number: '))
number_2 = int(input('Enter second number: '))

# %% [markdown]
# #### 2. Python Assignment Operators
#
# - Assignment operators are used to assign values to variables.

# %%
# assign 10 to a
a = 10

# assign 5 to b
b = 5


# assign the sum of a and b to a (Addition assignment)
print(a)

a = a + b
a += b

print(a)

# Output: 15

# %% [markdown]
# ### 3. Python Comparison Operators
#
# - Comparison operators compare two values/variables and return a boolean result: True or False.

# %%
a = 6

b = 9


# equal to operator
print('a == b =', a == b)
#
# # # not equal to operator
print('a != b =', a != b)
# #
# # # greater than operator
print('a > b =', a > b) # true
# #
# # # less than operator
print('a < b =', a < b) # false
#
# # greater than or equal to operator
print('a >= b =', a >= b)
#
# # less than or equal to operator
print('a <= b =', a <= b)
# Out:
# a == b = False
# a != b = True
# a > b = False
# a < b = True
# a >= b = False
# a <= b = True

# %% [markdown]
# #### 4. Python Logical Operators
# - Logical operators are used to check whether an expression is True or False. They are used in decision-making.

# %%
b = 6


# and
# or






print((a > 2) or (b < 5)) # true or false
# Out:
# True

# %% [markdown]
# #### 5. Membership operators
#
# - In Python, in and not in are the membership operators. They are used to test whether a value or variable is found in a sequence (`string`, `list`, `tuple`, `set` and `dictionary`).
# - In a `dictionary`, we can only test for the presence of a key, not the value.

# %%
myInfo = {
    'name' : 'sahil',
    'age' : 20,
    10 : 'abhi'
}
#
print("abhi" in myInfo.values())

print(myInfo.keys())

# %%
message = 'hello world'
# dict1 = {1:'b', 2:'a'} # dict , hashmap, hashset
myList = [1,2,3,5]
# print(dict1)

print(4 in myList)
# Out:
# False

# %%
# Create a list --> append
# list = ['a','b','c'...]
# dictionary = list,0

# if letter (a) in list --> boolean
# if 0 is present in values of my dictionary --> boolean

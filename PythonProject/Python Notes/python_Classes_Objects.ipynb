# %% [markdown]
# # 😎 Lets Play with Some Python Classes and Objects. 😎
#
#
# ### 🧐 Why `Classes and Objects` in Python are so Important and Needs Good Grasp. 🧐
#
#
# #### 🤘 Organization
# * Grouping related data and actions together like real-world things.
#
# #### 🤘 Reusability:
# *  Creating multiple instances with the same structure and functions, avoiding code repetition.
#
# #### 🤘 Complexity Management:
# *  Hiding internal details and controlling data access for cleaner code.
#
# #### 🤘 Extensibility:
# *  Building new, specialized classes based on existing ones (`inheritance`) and allowing different objects to respond to the same commands in their own way (`polymorphism`).

# %%
class Pragra:
    # <block of code>
    # variables
    # functions
    pass

# %%
class Walmart:

    # class attributes / class variables
    dairy_manager = "sahil"
    cosmetics_manager = "ravi"
    electronics_manager = "mayank"
    # payment_method = "credit card"
    pharmacy_manager = "loubna"

    def dairy(self):
        # function attribute / function variable
        requireMilk = True
        print("All dairy products")
        print("The dairy manager is :",self.dairy_manager)

    def cosmetics(self):
        print("All cosmetics products")
        print("The cosmetics manager is :",self.cosmetics_manager)

    def electronics(self):
        print("All electronics products")
        print("The electronics manager is :",self.electronics_manager)

    def payment_method(self):
        print("All payment methods")
        print("The payment method is :",self.payment_method)

# %%
obj_1 = Walmart() # obj_1 object name

# %%
type(obj_1)

# %%
print(obj_1.electronics())

# %%
obj_1.dairy_manager = "xyz"

# %%
obj_1.dairy_manager

# %%
obj_2 = Walmart()

# %%
obj_2.dairy_manager = "abc"

# %%
class Student():

    # this
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def introduce(self):
        print("My name is",self.name,"and I am",self.age,"years old.")

# %%
s1 = Student(name="Aman",age=20)
s1.introduce()

# %%
s2 = Student(name="Riya",age=21)
s2.introduce()

# %%
obj = Walmart()

# %%
obj.pharmacy_manager = "mayank"

# %%
obj.pharmacy_manager

# %%
electronic.electronics()

# %%
class house:
    def walls(self):
        print("walls access")


    def doors(self):
        print("doors access")


    def cabinets(self):
        print("cabinets access")


myobj = house().walls()
dadObj = house().cabinets()
momObj = house().doors()

# %%
sahil_obj = Walmart()

# %%
sahil_obj.dairy()

# %%
ravi_obj = Walmart()

# %%
ravi_obj.cosmetics()

# %%
class Pragra:

    def student_register(self):
        pass

    def teacher(self):
        pass

    def subject_register(self):
        pass

# %%
p1 = Pragra()

# %%
p1.teacherName()

# %%
p1.name

# %%
class House:  # house-1 (2 floor), #house-2 (3 floor)

    def floor(self):
        pass

    def windows(self):
        pass

# %%
class Calculator:

    def addition(self, number1, number2):
        return number1 + number2

    def multiplcation(self, number1, number2):
        return number1 * number2

    def division(self):
        pass

# %% [markdown]
# ### Python Classes
# * A class is considered a blueprint of objects.
#
# * We can think of the class as a sketch (prototype) of a house. It contains all the details about the floors, doors, windows, etc. Based on these descriptions, we build the house; the house is the object.
#
# * Since many houses can be made from the same description, we can create many objects from a class.

# %%
### How we can define a `class`

class YourBike:
    # local variable associated with class : yourBike # class variables -- class attributes
    name = "Ducati"
    gear = 4

    def gears(self, companyName):
        print("total gear are : ", self.gear)
        print("the company is :", companyName)

    def mirrors(self):
        mirror = 2  # local to function : mirrors
        print("the name of my bike is :", self.name)
        print("total mirrors are : ", mirror)

#1. come out of class
#2. create my object name = sahil_bike
# TODO: The variables of class are known as Attributes or class attributes

# %%
myfirstObject = YourBike()

# %%
## class variables
myfirstObject.gear

# %%
print(type(myfirstObject))

# %% [markdown]
# ### Python Objects
# * An object is called an instance of a class.
#
# * Suppose Bike is a class then we can create objects like bike1, bike2, etc from the class.
#
# `object_name = ClassName()`

# %%
# create object

class Bike:
    name = "Ducati"
    gear = 4


# create object of a class
bike1_object = Bike()
bike2_object = Bike()

# %%
class Pragra:
    subject = "python"  # class attribute or class variable

    def learning(self):  # local to class pragra
        print("I am learning python")

# %%
obj1 = Pragra()  # we can create object from a class.
obj2 = Pragra()

# whatever is inside your class - can be accessed by your object.
print(obj1.subject)
obj1.learning()

# %% [markdown]
# ### Access Class Attributes Using Objects

# %%
# modify the name property

# print(bike1_object.name)


#access the gear property
# print(bike1_object.gear)
print(bike1_object.name)
# modify the name property
bike1_object.name = "BMW"
bike2_object.gear = 7
print(bike1_object.name)
print(bike2_object.gear)

# %% [markdown]
# ### Python Class and Objects - Full Code

# %%
# define a class
class Bike:
    name = ""
    gear = 0


# create object of class
bike1 = Bike()
sahil_bike = Bike()

# access attributes and assign new values
bike1.gear = 11
bike1.name = "Mountain Bike"

sahil_bike.gear = 5
sahil_bike.name = "Hayabusa"

print("Name is : ", bike1.name, "Gears is : ", bike1.gear)
print("Name is : ", sahil_bike.name, "Gears is : ", sahil_bike.gear)

# %%
class Shapes:

    def circle(self):
        area_circle = "calculate"
        return area_circle

    def rectangle(self):
        area_rectangle = "calculate"
        return area_rectangle


salmans_object = Shapes()

# %% [markdown]
# #### Objects and Class Attributes

# %%
class Pragra:
    class_size = 10
    name = "sahil"

    def student_detail(self, name, course):
        self.name = name
        print(self.class_size)

    def student_subjects(self):
        pass

# %%
python_subject = Pragra()  # python_subject is an object
print(python_subject.class_size)

python_subject.class_size = 5
python_subject.name = "sahil"

print(python_subject.class_size)
print(python_subject.name)

ai_subject = Pragra()
print("this varible is taking val from class : ", ai_subject.class_size)
print(python_subject.name)

# %%
python_subject.student_subjects()

# %%
python = Pragra()

print("This is my class size from my class attribute :", python.class_size)

# changing class_size for object

python.class_size = 20

print("This is my class size from my class attribute :", python.class_size)

# %% [markdown]
# ### Create Multiple Objects of Python Class

# %%
# define a class
class Employee:
    # define a property
    employee_id = 0


# create two objects of the Employee class
employee1 = Employee()
employee2 = Employee()

# access property using employee1
employee1.myID = 1001
print(f"Employee ID: {employee1.myID}")
print("Employee ID:", employee1.myID)

# access properties using employee2
employee2.employeeID = 1002
print(f"Employee ID: {employee2.employeeID}")

# %%
class House:
    mirror = 0
    window = 0
    doors = 0
    lights = 0

    def beauty(self):
        pass

    def size(self):
        pass


h1 = House()
h1.mirror = 45

# %%
sahil_house = House()  # construction of object

print(sahil_house.mirror)
niharika_house = House()

# %% [markdown]
# ### init method-constructor
#
# - When you create an object from a class, it’s like building a house from a blueprint.
# - The __init__() method is like the setup/initialization step where you decide the color of the walls, number of rooms, etc.
# - The __init__() method is called automatically when you create an object from a class.
# - Without __init__(), every house would be blank — you’d have to set values one by one after construction.

# %%
# Simple Class Without __init__()

## __init__() --> magic method/ magic function / constructor
class Student:

    def learning(self):
        return "I am learning python"

    def exams(self):
        return "I am taking exams"


s1 = Student()
s2 = Student()

# You now have empty Student objects
print(s1)
print(s2)
# Out:
# <__main__.Student object at 0x7fd8f6b946d0>
# <__main__.Student object at 0x7fd8f6b94710>

# %%
s1.name = "sahil"
s1.name
# Out:
# 'sahil'

# %% [markdown]
# 1. __init__ with Parameters
#
# - You can pass multiple parameters to set up different attributes.

# %%
# ex with params
def addition(number1,number2):
    return number1+ number2


def addition2(number1,number2):
    return 23 + 65

addition(23,12)
# addition2(23,98)
# Out:
# 35

# %%
class Person:
    def __init__(self, name, age):
        self.name = name # self.name
        self.age = age

    def learning(self):
        return self.name,"is learning"


p0 = Person(name="sahil",age = 28)

p1 = Person(name = "Alice", age = 30)

p2 = Person(name = "Bob", age = 25)

p2.learning()
# Out:
# ('Bob', 'is learning')

# %% [markdown]
# Explanation:
#
# - **self**: refers to the current object (always the first parameter).
# - **name** and **age**: parameters passed when creating the object.
# - **self.name** and **self.age**: object attributes that store these values.

# %% [markdown]
# 2. Default Parameters in __init__
#
# Like normal functions, you can use default values in constructors.

# %%
class Dog:
    def __init__(self, name, breed="Mixed", age=1):
        self.name = name
        self.breed = breed
        self.age = age

d1 = Dog("Buddy")
d2 = Dog(name = "Max", breed = "Golden Retriever", age = 5)


print(d1.name, d1.breed, d1.age)
print(d2.name, d2.breed, d2.age)
# Out:
# Buddy Mixed 1
# Max Golden Retriever 5

# %% [markdown]
# ### 🤺 Hands on Keyboard and Eyes on Screen Time 🤺
#
# #### Question 1: Define a new class called `Car`. This class should have two `attributes`:
#
# * `color` (which should be initialized with a default value of "red")
# * `speed` (which should be initialized with a default value of 0)
#
# #### Question 2: Create two different `objects` (instances) of the Car class you defined in Question 1. Name them `car_one` and `car_two`.
#
# #### Question 3: For the `car_one` object:
#
# * Change its `color` attribute to "blue".
# * Change its `speed` attribute to 60.
#
# #### Question 4: Write Python code to print the color and speed of both car_one and car_two

# %% [markdown]
# ### 🤺 Hands on Keyboard and Eyes on Screen Time 🤺
#
# #### Question 1: Define a new class called `Rectangle`. This class should have two `attributes`:
#
# * `width` (which should be initialized with a default value of 5.0)
# * `height` (which should be initialized with a default value of 10.0)
#
# #### Question 2: Inside the `Rectangle` class, define a method called `calculate_perimeter`. This method should calculate and print the perimeter of the rectangle using the formula: Perimeter = 2 * (width + height). The method should access the width and height attributes of the Rectangle object it's called on.
#
# #### Question 3: Create two different objects (instances) of the Rectangle class you defined in Question 1. Name them `rectangle_one` and `rectangle_two`.
#
# #### Question 4:
#
# * For the `rectangle_one` object:
# * Change its `width` attribute to 7.5.
# * Change its `height` attribute to 12.0.
# * Call the calculate_perimeter method on rectangle_one.
# #### Question 5:
# * For the rectangle_two object:
# * Leave its width and height attributes at their default values.
# * Call the calculate_perimeter method on rectangle_two.

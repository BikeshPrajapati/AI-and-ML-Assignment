# %% [markdown]
# ## 🐍 Python Strings
#
#
# #### 📌 What is a String?
#
#
# - A string in Python is a sequence of characters enclosed in single quotes (' '), double quotes (" "), or triple quotes (''' ''' or """ """).

# %%
name = "Python"

city = 'Toronto'

message = "this is a single line string"


message = """This is a
second-line string
third-line string
"""

#


# integer --> 1
# strings --> "sahil", "yourname"
# float --> 2.6


# bikesh - variable sucks
# navdeep , harsimaran --> two quotes , single

# %% [markdown]
# ### 📌 Characteristics of Strings
# - Strings are immutable (cannot be changed after creation)
# - Indexed (each character has a position)
# - Can contain letters, numbers, spaces, and symbols

# %%
text = "Hello"
print(text[4])
# text[0] = 'h' ❌ Not allowed
# Out:
# o

# %%
name = "432y78352jb5j2njnjkn542nj2n4j@@@@---"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/49/5kk8dp7s6zxc60fsk0y_54hh0000gn/T/ipykernel_61337/1796717002.py in <module>
#       1 name = "messi"
# ----> 2 name[0] = 'k'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### 📌 String Indexing
# - Each character has an index starting from 0.

# %%
word = "Python"
print(word[0]) # P
print(word[3]) # h
print(word[-1]) # n




# palindrome --> nitin
print(word[::-1])
# Out:
# P
# h
# n
# nohtyP

# %% [markdown]
# ### 📌 Common String Functions (Methods)
# #### 1️⃣ upper() :
#
# Converts string to uppercase.

# %%
word = "python"
print(word.upper())



Functions --
# Out:
# PYTHON

# %% [markdown]
# #### 2️⃣ lower() :
#
# Converts string to lowercase.

# %%
text = "PYTHON"
print(text.lower())
# Out:
# python

# %% [markdown]
# #### 3️⃣ strip() :
#
# Removes leading and trailing spaces.

# %%
text = " hello "
print(text.strip())
# Out:
# hello

# %% [markdown]
# #### 4️⃣ replace(old, new):
#
# Replaces part of a string.

# %%
text = "I like Java"
print(text.replace("Java", "Python"))
# Out:
# I like Python

# %% [markdown]
# #### 5️⃣ split()
# Splits string into a list.

# %%
text = "apple banana orange"
print(text.split(" "))
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# #### 6️⃣ join()
# Joins list elements into a string.

# %%
words = ["I", "love", "Python"]
print(" ".join(words))
# Out:
# I love Python

# %% [markdown]
# #### 7️⃣ find()
# Finds index of substring.

# %%
text = "Python Programming"
print(text.find("Program"))
# Out:
# 7

# %% [markdown]
# #### 8️⃣ count()
# Counts occurrences of a character or word.

# %%
text = "banana"
print(text.count("a"))
# Out:
# 3

# %% [markdown]
# ### 📌 String Length
# Use len() to find string length.

# %%
text = "Python"
print(len(text))
# Out:
# 6

# %%
n = 10203004


n = list(str(n).strip(""))
n
# Out:
# ['1', '0', '2', '0', '3', '0', '0', '4']

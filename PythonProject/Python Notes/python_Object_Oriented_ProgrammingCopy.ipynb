# %% [markdown]
# # 😎 Lets Play with Some Python Object Oriented Programming. 😎
#
#
# ### 🧐 Python is a versatile programming language that supports various programming styles, including object-oriented programming (OOP) through the use of objects and classes.
#
#
# ### An object is any entity that has attributes and behaviors. For example, a parrot is an object. It has
#
# * attributes - name, age, color, etc.
# * behavior - dancing, singing, etc.

# %%
name = "kevin"
age = 20
salary = 100.0

print(type(name))
print(type(age))
print(type(salary))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
class Car:

    # class attribute or class variables
    modelName = ""
    modelCompany = 0

# create class object
mazda = Car()
mazda.modelName = "CX-5"
mazda.modelCompany = "Mazda" # object variable
mazda.color = "Blue" # attributes of mazda object
mazda.gears = "manual" # attributes of mazda object

# create another object
mercedes = Car()
mercedes.modelName = "C-Class"
mercedes.modelCompany = "Mercedes"
mercedes.gears = "automatic"
mercedes.color = "Red"

#
# access attributes
print(f"Sahil's Fav Model name: {mazda.modelName}")
print(f"Sahil's Fav Company name: {mazda.modelCompany}")
print(f"Sahil's Fav Color: {mercedes.color}")
# Out:
# Sahil's Fav Model name: CX-5
# Sahil's Fav Company name: Mazda
# Sahil's Fav Color: Red

# %%
class Car: # parent class (base class)
    pass

class myNewClass --> Car: # sahil (badminton,cricket) , (pizza, rice) ---> myFather (cricket), (rice) # child class (derived class)
    pass

# %% [markdown]
# ### But ok ....still what is OOP's
#
# #### Object-Oriented Programming (OOP) is a programming paradigm that organizes code around "objects" rather than just actions and data.
#
# * Inheritance
# * Encapsulation
# * Polymorphism

# %% [markdown]
# ### Python Inheritance
# * Inheritance is a way of creating a new class for using details of an existing class without modifying it.
#
# * The newly formed class is a derived class (or child class). Similarly, the existing class is a base class (or parent class).

# %%
class Pragra:

    def student(self):
        pass

    def subject(self):
        pass


class AIML(Pragra):
    pass

# %%
# base class
class Animal: # parent class or base class: class


    def eat(self):
        print( "I can eat!")

    def sleep(self):
        print("I can sleep!")

# derived class # child class
class Dog(Animal): # class childClassName(parentClassName)

    def bark(self):
        print("I can bark! Woof woof!!")


class Cat(Dog):

    def meow(self):
        print("Meow meow!!")

# Create object of the Dog class
dog = Dog()


#
# # Calling members of the base class
dog.eat()
dog.sleep()
#
# # Calling member of the derived class
dog.bark()
# Out:
# I can eat!
# I can sleep!
# I can bark! Woof woof!!

# %%
class Mammal:
    def mammal_info(self):
        print("Mammals can give direct birth.")

class WingedAnimal:
    def winged_animal_info(self):
        print("Winged animals can flap.")

class Bat(Mammal, WingedAnimal): #Bat childClass Bat(ParentClass, ParentClass)
    print("I am a bat")


# create an object of Bat class
b1 = Bat()

b1.mammal_info()
b1.winged_animal_info()

# %% [markdown]
# ### Polymorphism
#
# * Polymorphism is another important concept of object-oriented programming. It simply means more than one form.
#
# * That is, the same entity (method or operator or object) can perform different operations in different scenarios.

# %%
name = "sahil"

name_list = ["sahil","harman", "sunny"]

name_dict = {
    'name': 'sahil'
}

print(len(name),type(name))
print(len(name_list),type(name_list))
print(len(name_dict),type(name_dict))
# Out:
# 5 <class 'str'>
# 3 <class 'list'>
# 1 <class 'dict'>

# %%
class Shape: #parent

    def render(self):
        print("Printing Shape...")

    def new_Render(self):
        print("Printing New Shape...")

class Square(Shape): #child # method overriding

    def render(self):
        print("Printing Square...")

class Rectangle(Shape):

    def render(self):
        print("Printing Rectangle...")


rectangle_object = Rectangle()
rectangle_object.render()
rectangle_object.new_Render()

# create an object of Square
# square_object = Square()
# square_object.render()
# square_object.render_shape()

# rectangle_object = Rectangle()
# rectangle_object.render()
# Out:
# Printing Rectangle...
# Printing New Shape...

# %%
class Stack:
    # create a list variable

    def push(self,number):
        # write logic push

# %%
class myStack:

    # stack = []
    def push(self,x):
        pass

    # stack = [x]

    # stack = [x,y,z]
    def pop(self):
        pass --> x
    # stack = [x]

    # check --> stack is empty or not

# %% [markdown]
# ### Coding Time !!!
#
# #### Implement a last-in-first-out (LIFO) stack . The implemented stack should support all the functions of a normal stack (push, top, pop, and empty).
#
# #### Implement the MyStack class:
#
# * `push(int x)` Pushes element x to the top of the stack.
# * `pop()` Removes the element on the top of the stack and returns it.
# * `top()` Returns the element on the top of the stack.
# * boolean `empty()` Returns true if the stack is empty, false otherwise.

# %% [markdown]
# ### Dictionary
#
# #### Python dictionary is a data structure that stores the value in key: value pairs. Values in a dictionary can be of any data type and can be duplicated, whereas keys can't be repeated and must be immutable.
#
# 1. Keys are case sensitive which means same name but different cases of Key will be treated distinctly.
# 2. Keys must be immutable which means keys can be strings, numbers or tuples but not lists.
# 3. Duplicate keys are not allowed and any duplicate key will overwrite the previous value.
# 4. Internally uses hashing. Hence, operations like search, insert, delete can be performed in Constant Time.

# %%
elements = [1,2,3,4,5,6,7,8,9] # movie : 8 search time --> size of list o(9)

# %%
name = "sahil"
age = 28
money = 78.6

name_age = {
    'sahil': 28,
    'sonam': 23,
    28 : 'sahil',
    'money' : 78.6,
    'money' : 68.6,
    'Money' : 78.6,
    '8':'movie'
}

# %%
sahil_info = {
    'name':'Sahil',
    'favFood' : 'Pizza',
    'favMovie': 'Harry Potter',
    'phoneNumber' : 8638394,
    'bankBalance' : 1000000.00
}
print(sahil_info)

# %%
sahil_info_using_dict = dict(name='sahil', favFood='Pizza', favMovie='Harry Potter', phoneNumber=8638394, bankBalance=1000000.00)

print(sahil_info_using_dict)

# %% [markdown]
# ### Accessing Dictionary Elements
#
# #### Access values using keys, with error handling for missing keys.

# %%
sahil_info = {'name': 'Sahil', 'favFood': 'Pizza', 'favMovie': 'Harry Potter', 'phoneNumber': 8638394,
              'bankBalance': 1000000.00, 'favCar': "Mercedes"}



# wanted to extract the value of 'favFood'

print(sahil_info)

print(sahil_info['favColor'])

# %%
sahil_info.get('','blah blah')
# Out:
# 'blah blah'

# %%
sahil_info['favFood'] = "Burger"

# %%
print(sahil_info)

# %% [markdown]
# ### Modifying Dictionaries
#
# #### Dictionaries are mutable, allowing updates and additions.

# %%
my_dict = {'name': 'Alice', 'age': 25, 'city': 'New York', 'food': 'pizza', 'phoneNumber': 1234567890, 'country': 'USA'}


# Adding a new key-value pair




# Updating an existing key
# my_dict['age'] = 67
# my_dict['age1'] = 90
# #
# print(my_dict)
# #
# # # Using update() to add or update multiple key-value pairs
my_dict.update({'city': 'Boston', 'job': 'Engineer'})
print(my_dict)
# print(my_dict)  # Output: {'name': 'Alice', 'age': 26, 'city': 'Boston', 'country': 'USA', 'job': 'Engineer'}
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Boston', 'food': 'pizza', 'phoneNumber': 1234567890, 'country': 'USA', 'job': 'Engineer'}

# %% [markdown]
# ### Dictionary Methods

# %% [markdown]
# #### 📌 clear: Removes all key-value pairs from a dictionary, leaving it empty.

# %%
my_dict = {
    'name': 'Alice',
    'age': 25,
    'city': 'New York',
    'food' : 'pizza',
    'phoneNumber' : 1234567890
}
print(my_dict)
my_dict.clear()
print(my_dict)  # Output: {}
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York', 'food': 'pizza', 'phoneNumber': 1234567890}
# {}

# %% [markdown]
# #### 📌 copy : `dict.copy()` creates a **shallow copy** of a dictionary (a new dict with the same key→value references) so changes to the new dict don’t affect the original top-level keys.

# %%
# copy
my_dict = {'name': 'Alice',
           'age': 25
           }


new_dict = my_dict.copy()



new_dict['age'] = 26
# # my_dict['age'] = 30
print(my_dict)
print(new_dict)
# Out:
# {'name': 'Alice', 'age': 25}
# {'name': 'Alice', 'age': 26}

# %% [markdown]
# #### 📌 from keys : The fromkeys() method returns a dictionary with the specified keys and the specified value.

# %%
# from keys
myKeys = ['x', 'y', 'z']
new_dict = dict.fromkeys(myKeys, 2)
print(new_dict)
# Out:
# {'x': 2, 'y': 2, 'z': 2}

# %% [markdown]
# #### 📌 Using the .get() method: This method safely retrieves a value. It takes two optional arguments: the key to search for and an optional default value to return if the key is not found.

# %%
my_dict = {'name': 'Alice', 'age': 25}
# print(my_dict['phone'])

print(my_dict.get('age','This key is not found'))
# Out:
# 25

# %%
# get
my_dict = {'name': 'Alice', 'age': 25}
print(my_dict.get('name'))
print(my_dict.get('salary', 0))

# %% [markdown]
# #### 📌 the items() method is a built-in dictionary function that returns a view object containing all the dictionary's key-value pairs as a list of tuples.

# %%
# items

my_dict = {'name': 'Alice', 'age': 25}

print(my_dict.items())
for key, value in my_dict.items():
    print(f"{key} = {value}")
# Out:
# name = Alice
# age = 25

# %%
# keys
my_dict = {'name': 'Alice', 'age': 25,'phone':''}
print((my_dict.keys()))
# Out:
# dict_keys(['name', 'age', 'phone'])

# %%
# values
my_dict = {'name': 'Alice', 'age': 25,'phone':''}
print((my_dict.values()))
# Out:
# dict_values(['Alice', 25, ''])

# %%
# pop
my_dict = {'name': 'Alice', 'age': 25}
print(my_dict)
age_popped = my_dict.pop('age')

print(my_dict)
print(age_popped)
# Out:
# {'name': 'Alice', 'age': 25}
# {'name': 'Alice'}

# %%
# pop item
my_dict = {'name': 'Alice', 'age': 25,'city':'New York'}
poppedItem = my_dict.popitem()
print(poppedItem)  # Output: ('age', 25)
print(my_dict)  # Output: {'name': 'Alice'}
# Out:
# ('city', 'New York')
# {'name': 'Alice', 'age': 25}

# %%
# values
my_dict = {'name': 'Alice', 'age': 25}
print(list(my_dict.values()))  # Output: ['Alice', 25]

# %% [markdown]
# 🔹 Lists
# ##### Q1. Create a list of 5 fruits and:
# - Print the first fruit
# - Print the last fruit
# - Add a new fruit to the list
#
#
# 🔹 Dictionaries
# ##### Q2. Create a dictionary for a student with keys:
# `"name", "age", and "grade".`
# - Print the student’s name
# - Update the grade to a new value
# - Add a new key "city"

# %%
data = {"class":
            {"student":
                 {
                     "marks": {"math": 85},
                     "session":"school"
                }
            }
        }

# nested dictionary --> object inside an object
print(data['class']) # {'student': {'marks': {'math': 85}, 'session': 'school'}}
print(data['class']['student'])
print(data['class']['student']['session'])

# %%
myDict = {
    "coaching":{"centre":"pragra"},
    "name" : "sahil"
}

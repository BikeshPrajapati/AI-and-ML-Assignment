# %% [markdown]
# # 😎 Lets Play with Some Python Object Oriented Programming. 😎
#
#
# #### 🧐 Python is a versatile programming language that supports various programming styles, including object-oriented programming (OOP) through the use of objects and classes.
#
# #### 🧐 Object Oriented Programming is a fundamental concept in Python, empowering developers to build modular, maintainable and scalable applications.
#
# - OOP is a way of organizing code that uses objects and classes to represent real-world entities and their behavior.
# - In OOP, object has attributes thing that has specific data and can perform certain actions using methods.
#
#
# ### An object is any entity that has attributes and behaviors. For example, a parrot is an object. It has
#
# * attributes - name, age, color, etc.
# * behavior - dancing, singing, etc.

# %%
name = "kevin"
age = 20
salary = 100.0

print(type(name))
print(type(age))
print(type(salary))

# %%
class Car:

    # class attribute or class variables
    modelName = ""
    modelCompany = 0

# create class object
mazda = Car()
mazda.modelName = "CX-5"
mazda.modelCompany = "Mazda" # object variable
mazda.color = "Blue" # attributes of mazda object
mazda.gears = "manual" # attributes of mazda object

# %% [markdown]
# ### But ok ....still what is OOP's
#
# #### Object-Oriented Programming (OOP) is a programming paradigm that organizes code around "objects" rather than just actions and data.
#
# * Inheritance
# * Encapsulation
# * Polymorphism

# %% [markdown]
# ### Python Inheritance
# * Inheritance is a way of creating a new class for using details of an existing class without modifying it.
#
# * The newly formed class is a derived class (or child class). Similarly, the existing class is a base class (or parent class).
#
# #### Types of Inheritance:
#
# - Single Inheritance: A child class inherits from a single parent class.
# - Multiple Inheritance: A child class inherits from more than one parent class.
# - Multilevel Inheritance: A child class inherits from a parent class, which in turn inherits from another class.
# - Hierarchical Inheritance: Multiple child classes inherit from a single parent class.

# %%
# Define the parent class 'Animal'
class Animal:

    # Method to represent eating behavior
    def eating(self):
        return "Animal is eating..."

    # Method to represent sleeping behavior
    def sleeping(self):
        return "Animal is sleeping..."


# Define the child class 'Cat' that inherits from 'Animal'
class Cat(Animal):

    # Method unique to the 'Cat' class
    def meowing(self):
        return "Cat is meowing..."

# %%
obj1 = Cat()

# %%
obj1.eating()

# %%
obj1.sleeping()

# %%
class Father:

    def driving_skills(self):
        return "Driving skills"

class Mother:

    def teaching_skills(self):
        return "Teaching Skills"

class Child(Father,Mother):

    def playing_chess(self):
        return "Chess is fun"

# %%
c1 = Child()
c1.driving_skills()

# %%
obj1.meowing()

# %%
class Animal: # parent class

    def eat(self):
        return "I can eat!"

    def sleep(self):
        return "I can sleep!"

class Dog(Animal): # child class

    def bark(self):
        return "I can bark!"

# %%
dog_obj = Dog()
print(dog_obj.bark())


print(dog_obj.eat())
print(dog_obj.sleep())

# %%
class Account:

    def add_amount(self):
        pass

    def deduct_amoiunt(self):
        pass

class Savings(Account):

    def aadiotnal_benifits(self):
        pass

# %%
# Single Inheritance
class Dog:
    def __init__(self, name):
        self.name = name

    def display_name(self):
        print(f"Dog's Name: {self.name}")

class Labrador():  # Single Inheritance
    def sound(self):
        print("Labrador woofs")

# Multilevel Inheritance
class GuideDog(Labrador,Dog):  # Multilevel Inheritance
    def guide(self):
        print(f"{self.name}Guides the way!")

# Multiple Inheritance
class Friendly:
    def greet(self):
        print("Friendly!")

class GoldenRetriever(Dog, Friendly):  # Multiple Inheritance
    def sound(self):
        print("Golden Retriever Barks")

# Example Usage
# lab = Labrador("Buddy")
# lab.display_name()
# lab.sound()

# guide_dog = GuideDog("Max")
# guide_dog.display_name()
# guide_dog.guide()
#
retriever = GoldenRetriever("Charlie")
retriever.display_name()
retriever.greet()
retriever.sound()

# %%
class Mammal:
    def mammal_info(self):
        print("Mammals can give direct birth.")

class WingedAnimal:
    def winged_animal_info(self):
        print("Winged animals can flap.")

class Bat(Mammal, WingedAnimal): #Bat childClass Bat(ParentClass, ParentClass)
    print("I am a bat")


# create an object of Bat class
b1 = Bat()

b1.mammal_info()
b1.winged_animal_info()

# %% [markdown]
# ### Python Encapsulation
#
# * Encapsulation is one of the key features of object-oriented programming. Encapsulation refers to the bundling of attributes and methods inside a single class.
#
# * It prevents outer classes from accessing and changing attributes and methods of a class. This also helps to achieve data hiding.
#
# * In Python, we denote private attributes using underscore as the prefix i.e single `_` or double `__`. For example,

# %%
class Computer:


    def __init__(self):
        self.__maxprice = 900


    def sell(self):
        print("Selling Price: {}".format(self.__maxprice))
        # print("Selling Pirce",self.__maxprice)

    def setMaxPrice(self, price):
        self.__maxprice = price

computer_object = Computer()
computer_object.sell()

# # change the price
computer_object.__maxprice = 1000
computer_object.sell()
#
# # using setter function
computer_object.setMaxPrice(price=1000)
computer_object.sell()

# %% [markdown]
# ### Polymorphism
#
# Polymorphism means "many forms". It refers to the ability of an entity (like a function or object) to perform different actions based on the context.
#
# Technically, in Python, polymorphism allows same method, function or operator to behave differently depending on object it is working with. This makes code more flexible and reusable.
#
# #### Real Life Example: In a backend payment system, multiple payment options are available such as Credit Card, UPI, NetBanking and Wallet. All payment types use a common method named processPayment() but different implementations:
#
# - Credit Card Payment: validates card, talks to bank API
# - UPI Payment: redirects to UPI gateway
# - Wallet Payment: checks wallet balance
# - NetBanking Payment: redirects to bank login

# %%
class Animal:
    def sound(self):
        return "Some generic sound"

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):
        return "Meow"



# obj_1 = Animal()
# obj_1.sound()

obj_2 = Dog()
obj_2.sound()


# Polymorphic behavior
# animals = [Dog(), Cat(), Animal()]
# for animal in animals:
#     print(animal.sound())
# Out:
# 'Bark'

# %% [markdown]
# #### Polymorphism in Functions
# In Python, polymorphism lets functions accept different object types as long as they support needed behavior. Using duck typing, Python focuses on whether an object has right method not its type allowing flexible and reusable code.

# %%
class Pen:
    def use(self):
        return "Writing"

class Eraser:
    def use(self):
        return "Erasing"

def perform_task(tool):
    print(tool.use())

perform_task(tool = Pen())
perform_task(Eraser())

# %% [markdown]
# ### The Task: Create a program that calculates the area of different shapes. The catch? The calling code should not care which shape it is dealing with.
#
# 1. Create three classes: Rectangle, Circle, and Triangle.
# 2. Each class must have an `__init__` method to set its dimensions.
# 3. Each class must implement a method called `calculate_area()`.
#     - Rectangle: Area=length×width
#     - Circle: Area=π×radius
#     - Triangle: Area=0.5×base×height
#
# 4. Write a function called `print_area(shape)` that takes any shape object as an argument and calls its `calculate_area()` method.

# %%
import math
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        area = self.length* self.width
        return area

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        area = math.pi * (self.radius ** 2)
        return area

class Triangle:
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def calculate_area(self):
        area= 0.5 * (self.base * self.height)
        return area



def print_area(shape):
    return shape.calculate_area()


number1 = int(input("Please enter the length of rectangle: "))
number2 = int(input("Please enter the width of rectangle:"))
print_area(shape = Rectangle(number1, number2))
# Out:
# 276

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * (self.radius ** 2)

# Students should implement Rectangle and Triangle classes here...

shape_obj = Circle(5)
def print_area(shape):
    # This function demonstrates polymorphism
    print(f"The area is: {shape.calculate_area():.2f}")

print_area(shape_obj)
# Testing the implementation

# %%
class Rectangle:
    def __init__(self, length, breath):
        self.length = length
        self.breath = breath

    def calculate_area(self):
        area = self.length * self.breath
        return area


class Triangle:
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def calculate_area(self):
        area = self.base * self.height
        return area


class Circle:
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        area = self.radius * 3.14
        return area

def print_area(shape):
    return shape.calculate_area()


print_area(shape = Rectangle(5, 10))

# %% [markdown]
# ### What is Encapsulation in Python?
#
# - Encapsulation is a technique for hiding a class’ internal operations and exposing only the information required for external interactions.
# - It enables the creation of objects with clearly defined behaviors and properties, enhancing their usability and security.

# %% [markdown]
# #### Reasons to use encapsulation in python:
# 1. Only the necessary information is exposed and the implementation details are concealed from the outside world, the code is made more secure.
# 2. It allows for the creation of objects with clearly defined properties and behaviors, which facilitates the reuse of the code throughout the program.

# %%
# Public Access -> expose everything (class) -
# Protected Access -> protect attributes/functions from any change
# Private Access -> objects can only access certain exposed attributes/functions

# %% [markdown]
# ### Public access
#
# Public variables and methods are those that can be accessed by any part of the program. In Python, variables and methods are public by default, and they do not require any special keyword to be declared as public.

# %%
class Car:
    tyres = 4
    color = "red"

    def start(self):
        print("Car started")

    def stop(self):
        print("Car stopped")

class Mercedes(Car):
    pass

mercedesCar = Mercedes()
mercedesCar.stop()

# Car.color
# Out:
# 'red'

# %% [markdown]
# ### Private access
#
# Private variables and methods are those that can only be accessed within the class. In Python, private variables and methods are declared by prefixing them with double underscores (`__`).

# %%
class Car:
    __private_capacity = "2000cc"
    # private class variable
    public_capacity = "1000cc"

    def __start_engine(self):      # private method
        print("Engine started!")

    def drive(self):               # public method
        print("Engine driving!")

class Mercedes(Car):

    def myDrivePrivate(self):
        print(self.__private_capacity)

    def myDrivePublic(self):
        print(self.public_capacity)

merc_obj = Mercedes()
merc_obj.myDrivePublic()
# merc_obj.public_capacity
# merc_obj.__private_capacity
# Out:
# 1000cc

# %% [markdown]
# ### Protected access
#
# Protected variables and methods are those that can be accessed within the class and its subclasses. In Python, protected variables and methods are declared by prefixing them with a single underscore (_).

# %%
class Car:
    _mileage = 10

    def _drive(self):
        self._mileage += 10 # self._mileage = self._mileage + 10
        print(f"Mileage is now: {self._mileage}")

    def use_car(self):
        self._drive()

class SportsCar(Car):
    def turbo_boost(self):
        self._drive()  # Legal access
        print("Turbo boost activated!")

myCar = Car()
# myCar.use_car()


sportsCar = SportsCar()
sportsCar.turbo_boost()

# %% [markdown]
# ### Coding Test
#
# #### Create a class `BankAccount` with a private variable `balance`. Write methods to:
#
# - deposit money
# - withdraw money
# - check balance
#
# Make sure balance can't be accessed directly.

# %% [markdown]
# # Python Exceptions
#
# ### An exception is an unexpected event that occurs during program execution. For example,
#
# `divide_by_zero = 7 / 0`
#
# ### The above code causes an exception as it is not possible to divide a number by 0.

# %% [markdown]
# ### Python Logical Errors (Exceptions)
# #### Errors that occur at runtime (after passing the syntax test) are called exceptions or logical errors.
#
# ### For instance, they occur when we
#
# * try to open a file(for reading) that does not exist (FileNotFoundError)
# * try to divide a number by zero (ZeroDivisionError)
# * try to import a module that does not exist (ImportError) and so on.
#
# Whenever these types of runtime errors occur, Python creates an exception object.
#
# If not handled properly, it prints a traceback to that error along with some details about why that error occurred.

# %%
from docutils.io import InputError

try:
    divide_numbers = 90 / 0
    print(divide_numbers)
except ZeroDivisionError:
    print("You can not divide by zero")


# try --> # except


# try (try block) -> keyword where you will put all your logic
# except -> catch the exception and return a meaningful msg

# %%
def divide_numbers(num1, num2):
    try:
        return num1 / num2
    except ZeroDivisionError:
        return "You can not divide by zero"


divide_numbers(2, 9)

# %%
def divide_numbers(num1, num2):
    try:
        return num1 / num2


divide_numbers(2, 0)

# %% [markdown]
# #### Example of Python Error : https://www.programiz.com/python-programming/exceptions

# %% [markdown]
# ### Python try...except Block
# #### The try...except block is used to handle exceptions in Python. Here's the syntax of try...except block:

# %%
try:
    x = int("hello")
except ValueError:
    print("You tried converting text into a number!")

# %%
x = int("hello")

# %%
# TODO : Give an example using numerator and denominator

try:
    print("my code starts from here")
    num1 = int(input("Enter a number1: "))
    num2 = int(input("Enter a number2: "))
    remainder = num1 / num2
    print(remainder)
except ZeroDivisionError:
    print("Divide by Zero- which is not possible")
except ValueError:
    print("Input must be a number")

# %% [markdown]
# ### Catching Specific Exceptions in Python

# %% [markdown]
# #### For each `try` block, there can be zero or more `except` blocks. Multiple `except` blocks allow us to handle each `exception` differently.
#
# #### The argument type of each except block indicates the type of exception that can be handled by it. For example,

# %%
numbers = [2, 4, 6, 8]

print(numbers[4])

# %%
numbers = [2, 4, 6, 8]
try:
    print(numbers[7])
except IndexError:
    print("Index out of range or not found")

# Output: Index Out of Bound

# %% [markdown]
# #### Coding Test
#
# 1. Write a program that accesses the 5th element in a list [10, 20, 30].
#
# 👉 Handle `IndexError`.
#
# 2. Write a function that tries to add a number and a string:
#
#     `result = 5 + "hello"`
#
# 👉 Handle the `TypeError`

# %% [markdown]
# ### Exception handling with try, except, else, and finally
# - **Try**: This block will test the excepted error to occur
# - **Except**:  Here you can handle the error
# - **Else**: If there is no exception then this block will be executed
# - **Finally**: Finally block always gets executed either exception is generated or not

# %% [markdown]
# #### Else Clauses in Python
#
# The code enters the else block only if the try clause does not raise an exception.
#
# - Example: Else block will execute only when no exception occurs.

# %%
# Python code to illustrate working of try()
def divide(x, y):
    try:
        result = x // y
    except ZeroDivisionError:
        print("Sorry ! You are dividing by zero ")
    else:
        print("Yeah ! Your answer is :", result)

# Look at parameters and note the working of Program
divide(3, 2)
# divide(3, 0)

# %% [markdown]
# ### Finally keyword in Python
#
# - In Python, the `finally` keyword is used in a `try-except-finally` block to define a section of code that will always execute, regardless of whether an exception occurs or not.
# - It guarantees predictable code behavior, maintaining program stability even when errors arise.
# - The finally block always executes after normal termination of try block or after try block terminates due to some exception.

# %%
try:
    result = 10 / 2
except ZeroDivisionError:
    print("Caught division by zero error.")
finally:
    print("This block always executes.")

# %%
# Python code to illustrate
# working of try()
def divide(x, y):
    try:
        result = x // y
    except ZeroDivisionError:
        print("Sorry ! You are dividing by zero ")
    else:
        print("Yeah ! Your answer is :", result)
    finally:
        # this block is always executed
        # regardless of exception generation.
        print('This is always executed')

# 13,9,5

# Look at parameters and note the working of Program

divide(3, 0)
# Out:
# Sorry ! You are dividing by zero
# This is always executed

# %% [markdown]
# #### Python `Raise` Keyword
#
# - The `raise` keyword in Python is used to manually trigger an exception.
# - It tells Python: “Hey, throw this error right now!”
# - You can raise built-in exceptions (ValueError, ZeroDivisionError, etc.) or your own custom exceptions.
# - The raise keyword raises an error and stops the control flow of the program.

# %%
def check_age(age):
    if age < 0:
        raise ValueError()
    return age


check_age(-12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/49/5kk8dp7s6zxc60fsk0y_54hh0000gn/T/ipykernel_4204/4028318243.py in <module>
#       5
#       6
# ----> 7 check_age(-12)
#
# /var/folders/49/5kk8dp7s6zxc60fsk0y_54hh0000gn/T/ipykernel_4204/4028318243.py in check_age(age)
#       1 def check_age(age):
#       2     if age < 0:
# ----> 3         raise ValueError()
#       4     return age
#       5
#
# ValueError:

# %%
## check the length of your name < 5 : raise ValueError (length does not satisfy)

# %% [markdown]
# ### Defining Custom Exceptions
# In Python, we can define custom exceptions by creating a new class that is derived from the built-in `Exception` class.

# %%
def test():
    pass

# %%
class AgeBelowZeroError(Exception):
    pass

def check_age(age):
    try:
        if age < 0:
            raise AgeBelowZeroError()
        return age
    except InputError:
        print("Caught custom error:")

check_age(-24)
# Out:
# Caught custom error:

# %%
class MyError(Exception):
    pass

try:
    raise MyError("Something went wrong")
except MyError:
    print("Caught custom error:")
# Out:
# Caught custom error:

# %%
myList = [1, 2, 4, 5, 4, 6]


class FiveInMyList(Exception):
    pass


for element in myList:
    if element == 5:
        raise FiveInMyList("Element cannot be 5 or I do not expect 5 in my list")

    print(element)
# Out:
# ---------------------------------------------------------------------------
# FiveInMyList                              Traceback (most recent call last)
# /var/folders/49/5kk8dp7s6zxc60fsk0y_54hh0000gn/T/ipykernel_4204/3220499716.py in <module>
#       8 for element in myList:
#       9     if element == 5:
# ---> 10         raise FiveInMyList("Element cannot be 5 or I do not expect 5 in my list")
#      11
#      12     print(element)
#
# FiveInMyList: Element cannot be 5 or I do not expect 5 in my list

# %%
# define Python user-defined exceptions

class NotMinimumAgeException(Exception):
    pass  # this does nothing


number = 18

try:
    input_num = int(input("Enter a number: "))
    if input_num < number:
        raise NotMinimumAgeException
    else:
        print("Eligible to Vote")

except NotMinimumAgeException:
    print("Exception occurred: Invalid Age")

print(type(NotMinimumAgeException))

# %%
class InvalidInterestException(Exception):
    pass


# actual function - room
def caculateSimpleInterest(p, r, t):
    try:
        if rate < 1:
            raise InvalidInterestException

        # logging function
        simple_interest = (principal * rate * time) / 100
        return simple_interest

    except InvalidInterestException:
        return 'Invalid Interest'


principal = float(input('Enter your principal: '))
rate = float(input('Enter your rate: '))
time = float(input('Enter your time: '))
print(caculateSimpleInterest(p=principal, r=rate, t=time))

# %% [markdown]
# ### Questions
#
# - Create a function that creates a password and then check the length of password --> if length < 6 then raise an exception. Create a custom exception PasswordTooShortError

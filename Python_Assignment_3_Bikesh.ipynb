# %% [markdown]
# ### Python Assignment - 3

# %% [markdown]
# #### Section A : EASY (10 Questions)
# Type Casting(1-5)
# 1. Convert the string "100" into an integer and print the result.

# %%
Number = "100"

print(int(Number))
print(type(int(Number)))
# Out:
# 100
# <class 'int'>

# %% [markdown]
# 2. Convert the integer 25 into a float

# %%
Num = 25

print(float(Num))
print(type(float(Num)))
# Out:
# 25.0
# <class 'float'>

# %% [markdown]
# 3. Convert the float 9.8 into an integer

# %%
 Rate = 9.8

print(int(Rate))
print(type(int(Rate)))
# Out:
# 9
# <class 'int'>

# %% [markdown]
# 4. Convert the number 50 inot a string and print its type

# %%
number  = 50

print(str(number))
print(type(str(number)))
# Out:
# 50
# <class 'str'>

# %% [markdown]
# 5. Convert the string "12.5" into a float and add 2.5 to it

# %%
Score = "12.5"

print(float(Score) + 2.5)
# Out:
# 15.0

# %% [markdown]
# Dictinaries (6-10)
#
# 6. Create a dictionary with keys: name, age, and city, and print it.

# %%
 Profile = dict( name = "harry", age = 25, city = "Toronto")

print(Profile)
# Out:
# {'name': 'harry', 'age': 25, 'city': 'Toronto'}

# %% [markdown]
# 7. Access and print the value of the key age from  a dictonary.

# %%
Profile_Age = Profile['age']

print(Profile_Age)
# Out:
# 25

# %% [markdown]
# 8. Add a new key country to an exisitng dictionary.

# %%
Profile['country'] = "Canada"

print(Profile)
# Out:
# {'name': 'harry', 'age': 25, 'city': 'Toronto', 'country': 'Canada'}

# %% [markdown]
# 9. Update the value of an exisitng key in a dictionary.

# %%
Profile.update( age = 30)

print(Profile)
# Out:
# {'name': 'harry', 'age': 30, 'city': 'Toronto', 'country': 'Canada'}

# %% [markdown]
# 10. print all the keys of a dictionary

# %%
print(Profile.keys())
# Out:
# dict_keys(['name', 'age', 'city', 'country'])

# %% [markdown]
# #### Section B: Medium (10 Question)
# Type Casting (11-15)
#
# 11. Take two strings "10" and "20", convert them into integers, and print their sum..

# %%
Num1 = "10"
Num2 = "20"

print(int(Num1) +int(Num2))
# Out:
# 30

# %% [markdown]
# 12. Convert a list of strings ["1", "2", "3"] into a list of integers.

# %%
numbers = ["1","2", "3"]

new_list = list()
for n in numbers:
    new_list.append((int(n)))

print(new_list)
# Out:
# [1, 2, 3]

# %% [markdown]
# 13. Convert the integer 0 into a boolean and print the result.

# %%
 num = 0

print(bool(num))
# Out:
# False

# %% [markdown]
# 14. Convert the float 0.0 into a boolean and print the result.

# %%
Float_number = 0.0

print(bool(Float_number))
# Out:
# False

# %% [markdown]
# 15. Convert a boolean True into an integer and print the output.

# %%
 Value = True

print(int(Value))
# Out:
# 1

# %% [markdown]
# Dictionaries (16 -20)
#
# 16. Create a dictionary of 3 students with their marks and print the dictionary.

# %%
Studnet_info = dict( Harry = 85, Celin = 68, Robert = 90)

print(Studnet_info)
# Out:
# {'Harry': 85, 'Celin': 68, 'Robert': 90}

# %% [markdown]
# 17. Check whether a key exists in a dictionary.

# %%
if "Harry" in Studnet_info:
    print("key exists")

else:
    print("Key doesnot exists")


print(Studnet_info.get('Conner',"Key doesnot exist"))
# Out:
# key exists
# Key doesnot exist

# %% [markdown]
# 18. Iterate through a dictionary and print all keys and values.

# %%
for key, values in Studnet_info.items():
    print(f"{key} = {values}")
# Out:
# Harry = 85
# Celin = 68
# Robert = 90

# %% [markdown]
# 19. Remove a key from a dictionary.

# %%
Studnet_info.popitem()
print(Studnet_info)
# Out:
# {'Harry': 85}

# %% [markdown]
# 20. Count the number of key-value pairs in a dictionary.

# %%
count = len(Studnet_info)
print(count)
# Out:
# 1
